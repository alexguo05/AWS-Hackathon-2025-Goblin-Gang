# %% [markdown]
# # AirSim Drone Simulation Analysis Demo
#
# This notebook demonstrates how to analyze data collected from AirSim drone simulations.
#
# ## Prerequisites
# 1. Run a simulation using `python scripts/run_simulation.py`
# 2. Ensure data is collected in the `data/` directory

# %%
import sys
import os
from pathlib import Path

# Add src directory to path
sys.path.append(str(Path.cwd().parent / 'src'))

from data_analyzer import DataAnalyzer
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
